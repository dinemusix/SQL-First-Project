# %%
# Work is written as wrok just to remember.
# Download the files just uploaded on github
# Download My SQL WORKBENCH ---(MI)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mysql.connector as MySQL

# %%
Data = MySQL.connect(
  host="localhost",
  user="root",
  password="12345678",
  database="divyansh"
)

# %%
Cursor = Data.cursor()

# %%
# Well the file which is of .sql type has many data in it! I will use only one out of it.
Cursor.execute("Select * from customer_list;")

# %%
Output = Cursor.fetchall()

# %%
for x in Output: 
    print(x)
# Out:
# (218, 'VERA MCCOY', '1168 Najafabad Parkway', '40301', '886649065861', 'Kabul', 'Afghanistan', 'active', 1)
# (441, 'MARIO CHEATHAM', '1924 Shimonoseki Drive', '52625', '406784385440', 'Batna', 'Algeria', 'active', 1)
# (69, 'JUDY GRAY', '1031 Daugavpils Parkway', '59025', '107137400143', 'Bchar', 'Algeria', 'active', 2)
# (176, 'JUNE CARROLL', '757 Rustenburg Avenue', '89668', '506134035434', 'Skikda', 'Algeria', 'active', 1)
# (320, 'ANTHONY SCHWAB', '1892 Nabereznyje Telny Lane', '28396', '478229987054', 'Tafuna', 'American Samoa', 'active', 2)
# (528, 'CLAUDE HERZOG', '486 Ondo Parkway', '35202', '105882218332', 'Benguela', 'Angola', 'active', 1)
# (383, 'MARTIN BALES', '368 Hunuco Boulevard', '17165', '106439158941', 'Namibe', 'Angola', 'active', 1)
# (381, 'BOBBY BOUDREAU', '1368 Maracabo Boulevard', '32716', '934352415130', 'South Hill', 'Anguilla', 'active', 2)
# ...

# %%
OutputDF = pd.DataFrame(Output)

# %%
OutputDF
# Out:
#        0                    1                                   2      3  \
# 0    218           VERA MCCOY              1168 Najafabad Parkway  40301
# 1    441       MARIO CHEATHAM              1924 Shimonoseki Drive  52625
# 2     69            JUDY GRAY             1031 Daugavpils Parkway  59025
# 3    176         JUNE CARROLL               757 Rustenburg Avenue  89668
# 4    320       ANTHONY SCHWAB         1892 Nabereznyje Telny Lane  28396
# ..   ...                  ...                                 ...    ...
# 594  303  WILLIAM SATTERFIELD             687 Alessandria Parkway  57587
# 595  213      GINA WILLIAMSON                1001 Miyakonojo Lane  67924
# 596    7         MARIA MILLER  900 Santiago de Compostela Parkway  93896
# 597  553             MAX PITT             1917 Kumbakonam Parkway  11892
# 598  438       BARRY LOVELACE                  1836 Korla Parkway  55405
#
#                 4           5               6       7  8
# ...

# %%
Output
# Out:
# [(218,
#   'VERA MCCOY',
#   '1168 Najafabad Parkway',
#   '40301',
#   '886649065861',
#   'Kabul',
#   'Afghanistan',
#   'active',
#   1),
#  (441,
#   'MARIO CHEATHAM',
#   '1924 Shimonoseki Drive',
#   '52625',
#   '406784385440',
#   'Batna',
#   'Algeria',
#   'active',
#   1),
#  (69,
#   'JUDY GRAY',
#   '1031 Daugavpils Parkway',
#   '59025',
#   '107137400143',
#   'Bchar',
#   'Algeria',
#   'active',
#   2),
#  (176,
#   'JUNE CARROLL',
#   '757 Rustenburg Avenue',
#   '89668',
#   '506134035434',
#   'Skikda',
#   'Algeria',
#   'active',
#   1),
#  (320,
#   'ANTHONY SCHWAB',
#   '1892 Nabereznyje Telny Lane',
#   '28396',
#   '478229987054',
#   'Tafuna',
#   'American Samoa',
#   'active',
#   2),
#  (528,
#   'CLAUDE HERZOG',
#   '486 Ondo Parkway',
#   '35202',
#   '105882218332',
#   'Benguela',
#   'Angola',
#   'active',
#   1),
#  (383,
#   'MARTIN BALES',
#   '368 Hunuco Boulevard',
#   '17165',
#   '106439158941',
#   'Namibe',
#   'Angola',
#   'active',
# ...

# %%
# plt.bar(ZeroValue,EightValue)

# %%
MOutputDF = OutputDF[0:10]

# %%
MOutputDF
# Out:
#      0                 1                              2      3             4  \
# 0  218        VERA MCCOY         1168 Najafabad Parkway  40301  886649065861
# 1  441    MARIO CHEATHAM         1924 Shimonoseki Drive  52625  406784385440
# 2   69         JUDY GRAY        1031 Daugavpils Parkway  59025  107137400143
# 3  176      JUNE CARROLL          757 Rustenburg Avenue  89668  506134035434
# 4  320    ANTHONY SCHWAB    1892 Nabereznyje Telny Lane  28396  478229987054
# 5  528     CLAUDE HERZOG               486 Ondo Parkway  35202  105882218332
# 6  383      MARTIN BALES           368 Hunuco Boulevard  17165  106439158941
# 7  381    BOBBY BOUDREAU        1368 Maracabo Boulevard  32716  934352415130
# 8  359    WILLIE MARKHAM           1623 Kingstown Drive  91299  296394569728
# 9  560  JORDAN ARCHULETA  1229 Varanasi (Benares) Manor  40195  817740355461
#
#                  5               6       7  8
# 0            Kabul     Afghanistan  active  1
# ...

# %%
ZeroValue= MOutputDF[0] 
EightValue= MOutputDF[8]

# %%
# plt.bar(ZeroValue,EightValue)
# plt.scatter(ZeroValue,EightValue)
plt.plot(ZeroValue,EightValue)
